# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/article/blob/main/Sustainability_outcomes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Subjects "Basics of Ecology" outputs and "Green Transition Action Fields" program outputs correlation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Define learning outcomes for both subjects
ecology_outcomes = [
    "Knowing general aims of ecology and its main branches",
    "Knowing main theories and central principles of ecology",
    "Knowing the principles of flux of energy and matter in ecosystems",
    "Ability to interpret professional information from viewpoint of ecology",
    "Experience in reading and interpreting ecological literature",
    "Experience in planning research activities"
]

green_outcomes = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Compute TF-IDF vectors
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(ecology_outcomes + green_outcomes)

# Compute similarity matrix
similarity_matrix = cosine_similarity(vectors[:len(ecology_outcomes)], vectors[len(ecology_outcomes):])

# Find best matches
def match_outcomes(similarity_matrix, ecology_outcomes, green_outcomes):
    for i, row in enumerate(similarity_matrix):
        best_match_idx = np.argmax(row)
        best_match_score = row[best_match_idx]
        print(f"'{ecology_outcomes[i]}' matches best with '\n  -> {green_outcomes[best_match_idx]}' (Similarity: {best_match_score:.2f})")

match_outcomes(similarity_matrix, ecology_outcomes, green_outcomes)
# Out:
# 'Knowing general aims of ecology and its main branches' matches best with '
#   -> Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change' (Similarity: 0.07)
# 'Knowing main theories and central principles of ecology' matches best with '
#   -> Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change' (Similarity: 0.08)
# 'Knowing the principles of flux of energy and matter in ecosystems' matches best with '
#   -> Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change' (Similarity: 0.31)
# 'Ability to interpret professional information from viewpoint of ecology' matches best with '
#   -> Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change' (Similarity: 0.18)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define learning outcomes
learning_outcomes_ecology = [
    "Knowing general aims of ecology and its main branches",
    "Knowing main theories and central principles of ecology",
    "Knowing the principles of flux of energy and matter in ecosystems",
    "Ability to interpret professional information from viewpoint of ecology",
    "Experience in reading and interpreting ecological literature",
    "Experience in planning research activities"
]

learning_outcomes_green_transition = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Combine all learning outcomes for vectorization
all_outcomes = learning_outcomes_ecology + learning_outcomes_green_transition

# Compute TF-IDF vectors
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_outcomes)

# Compute cosine similarity
similarity_matrix = cosine_similarity(tfidf_matrix[:len(learning_outcomes_ecology)],
                                      tfidf_matrix[len(learning_outcomes_ecology):])

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(similarity_matrix, annot=True, cmap="coolwarm", xticklabels=["Sustainable Practices", "Energy & Resource Optimization", "Waste Management"],
            yticklabels=["Ecology Aims", "Ecology Theories", "Energy & Matter Flux", "Info Interpretation", "Literature Interpretation", "Research Planning"])
plt.title("Matching of Learning Outcomes between Subjects")
plt.xlabel("Green Transition Action Fields")
plt.ylabel("Basics of Ecology")
plt.show()

# %% [markdown]
# Subjects "Applied Mathematics" outputs and "Green Transition Action Fields" program outputs correlation

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define learning outcomes
math_outcomes = [
    "Ability to perform arithmetic operations with matrices, calculate determinants up to the fifth order.",
    "Ability to use matrix algebra methods in solving systems of linear equations.",
    "Ability to manipulate vectors in two and three dimensions, and to solve geometrical problems using vectors",
    "Familiarity with various representations, classes and types of functions of one real variable, ability to determine their domain and range",
    "Knowing the basic rules for differentiation and be able to find derivatives of elementary functions",
    "Familiarity with the basic techniques of integration"
]

green_outcomes = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Combine all outcomes for vectorization
all_outcomes = math_outcomes + green_outcomes

# Convert text data into TF-IDF vectors
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_outcomes)

# Compute cosine similarity
similarity_matrix = cosine_similarity(tfidf_matrix[:len(math_outcomes)], tfidf_matrix[len(math_outcomes):])

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(similarity_matrix, annot=True, cmap="coolwarm", xticklabels=["Green 1", "Green 2", "Green 3"],
            yticklabels=["Math 1", "Math 2", "Math 3", "Math 4", "Math 5", "Math 6"])
plt.title("Similarity Between Applied Mathematics and Green Transition Outcomes")
plt.xlabel("Green Transition Outcomes")
plt.ylabel("Applied Mathematics Outcomes")
plt.show()

# %% [markdown]
# Subjects "Engineering Graphics" outputs and "Green Transition Action Fields" program outputs correlation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define the learning outcomes
engineering_graphics = [
    "Overview of standards and knowing how to handle reference material",
    "Knowing the norms concerning the formatting of drawings and techniques of representation",
    "Acquires skills of drawing techniques",
    "Preparing drawings in accordance with the applicable norms",
    "Reading and supplementing drawings"
]

green_transition = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Combine all learning outcomes for vectorization
all_outcomes = engineering_graphics + green_transition

# Compute TF-IDF and cosine similarity
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_outcomes)
similarity_matrix = cosine_similarity(tfidf_matrix)

# Convert similarity matrix to DataFrame for readability
df_similarity = pd.DataFrame(similarity_matrix,
                             index=["EG1", "EG2", "EG3", "EG4", "EG5", "GT1", "GT2", "GT3"],
                             columns=["EG1", "EG2", "EG3", "EG4", "EG5", "GT1", "GT2", "GT3"])

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_similarity, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Learning Outcome Similarity Between Subjects")
plt.show()

# %% [markdown]
# Subjects "Applied Physics" outputs and "Green Transition Action Fields" program outputs correlation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns

# Learning outcomes for both subjects
applied_physics = [
    "Defining physics basic concepts and describing, how physics quantities are related to each other",
    "Explaining physical constitutions and processes in own words, graphically or using real life examples and connecting them to applications in modern technology",
    "Solving physics problems, choosing right formulas and converting physics units"
]

green_transition = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Combine all learning outcomes for vectorization
all_outcomes = applied_physics + green_transition

# Convert text into numerical vectors using TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_outcomes)

# Compute cosine similarity between Applied Physics and Green Transition outcomes
similarity_matrix = cosine_similarity(tfidf_matrix[:3], tfidf_matrix[3:])

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(similarity_matrix, annot=True, cmap="Blues", xticklabels=["GT LO1", "GT LO2", "GT LO3"],
            yticklabels=["AP LO1", "AP LO2", "AP LO3"], fmt=".2f")
plt.title("Similarity between Applied Physics and Green Transition Learning Outcomes")
plt.xlabel("Green Transition Action Fields")
plt.ylabel("Applied Physics")
plt.show()

# %% [markdown]
# Subjects "Basics of CAD Systems" outputs and "Green Transition Action Fields" program outputs correlation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define learning outcomes
cad_outcomes = [
    "Ability to use the necessary AutoCAD drawing techniques",
    "Knowing how to prepare a drawing, and form it according to the rules of the ISO standard",
    "Ability to process and convert drawings for transmission and presentation"
]

green_outcomes = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Combine all outcomes
all_outcomes = cad_outcomes + green_outcomes

# Convert text data into TF-IDF features
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_outcomes)

# Compute cosine similarity
similarity_matrix = cosine_similarity(tfidf_matrix[:3], tfidf_matrix[3:])

# Visualization
fig, ax = plt.subplots(figsize=(8, 6))
cax = ax.matshow(similarity_matrix, cmap='coolwarm', vmin=0, vmax=1)
plt.colorbar(cax)
ax.set_xticks(range(len(green_outcomes)))
ax.set_yticks(range(len(cad_outcomes)))
ax.set_xticklabels([f'Green LO {i+1}' for i in range(len(green_outcomes))], rotation=45, ha="left")
ax.set_yticklabels([f'CAD LO {i+1}' for i in range(len(cad_outcomes))])
plt.title("Matching Learning Outcomes between CAD and Green Transition Fields")
plt.show()

# Print similarity scores
for i, cad_lo in enumerate(cad_outcomes):
    for j, green_lo in enumerate(green_outcomes):
        print(f"Similarity between '{cad_lo}' and '{green_lo}': {similarity_matrix[i, j]:.2f}")
# Out:
# Similarity between 'Ability to use the necessary AutoCAD drawing techniques' and 'Competence in sustainable practices and renewable technologies': 0.00
# Similarity between 'Ability to use the necessary AutoCAD drawing techniques' and 'Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change': 0.26
# Similarity between 'Ability to use the necessary AutoCAD drawing techniques' and 'Organisation and optimisation of processes for effective waste management': 0.00
# Similarity between 'Knowing how to prepare a drawing, and form it according to the rules of the ISO standard' and 'Competence in sustainable practices and renewable technologies': 0.03
# Similarity between 'Knowing how to prepare a drawing, and form it according to the rules of the ISO standard' and 'Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change': 0.26
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import jaccard_score
from scipy.spatial.distance import cosine

# Define learning outcomes
cad_outcomes = [
    "Ability to use the necessary AutoCAD drawing techniques",
    "Knowing how to prepare a drawing, and form it according to the rules of the ISO standard",
    "Ability to process and convert drawings for transmission and presentation"
]

green_outcomes = [
    "Competence in sustainable practices and renewable technologies",
    "Emphasis on energy saving and optimisation of resource use, the ability to cope with the consequences of climate change",
    "Organisation and optimisation of processes for effective waste management"
]

# Combine all outcomes
all_outcomes = cad_outcomes + green_outcomes

# Convert text data into TF-IDF features
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_outcomes)

# Compute cosine similarity
similarity_matrix = cosine_similarity(tfidf_matrix[:3], tfidf_matrix[3:])

# Manual verification of cosine similarity
manual_cosine_similarities = []
for i in range(3):
    for j in range(3):
        vec1 = tfidf_matrix[i].toarray()[0]
        vec2 = tfidf_matrix[j+3].toarray()[0]
        manual_cosine_similarity = 1 - cosine(vec1, vec2)
        manual_cosine_similarities.append(manual_cosine_similarity)

# Convert manual results to matrix
manual_similarity_matrix = np.array(manual_cosine_similarities).reshape(3, 3)

# Compute Jaccard Similarity for verification
binary_matrix = (tfidf_matrix > 0).astype(int)
jaccard_matrix = np.zeros((3, 3))
for i in range(3):
    for j in range(3):
        jaccard_matrix[i, j] = jaccard_score(binary_matrix[i].toarray()[0], binary_matrix[j+3].toarray()[0])

# Visualization
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
cmap = 'coolwarm'

# Plot Cosine Similarity (Sklearn)
axes[0].matshow(similarity_matrix, cmap=cmap, vmin=0, vmax=1)
axes[0].set_title("Cosine Similarity (Sklearn)")

# Plot Manual Cosine Similarity
axes[1].matshow(manual_similarity_matrix, cmap=cmap, vmin=0, vmax=1)
axes[1].set_title("Manual Cosine Similarity")

# Plot Jaccard Similarity
axes[2].matshow(jaccard_matrix, cmap=cmap, vmin=0, vmax=1)
axes[2].set_title("Jaccard Similarity")

for ax in axes:
    ax.set_xticks(range(len(green_outcomes)))
    ax.set_yticks(range(len(cad_outcomes)))
    ax.set_xticklabels([f'Green LO {i+1}' for i in range(len(green_outcomes))], rotation=45, ha="left")
    ax.set_yticklabels([f'CAD LO {i+1}' for i in range(len(cad_outcomes))])

plt.show()

# Print similarity scores
print("\nCosine Similarity (Sklearn):")
print(similarity_matrix)
print("\nManual Cosine Similarity:")
print(manual_similarity_matrix)
print("\nJaccard Similarity:")
print(jaccard_matrix)

# References:
# 1. Manning, C. D., Raghavan, P., & Schütze, H. (2008). Introduction to Information Retrieval.
# 2. Rajaraman, A., & Ullman, J. D. (2011). Mining of Massive Datasets.
# 3. Scikit-learn Documentation: https://scikit-learn.org/stable/
# Out:
# Cosine Similarity (Sklearn):
# [[0.         0.2566675  0.        ]
#  [0.02829698 0.25695827 0.07517471]
#  [0.07632629 0.12232554 0.1636575 ]]
#
# Manual Cosine Similarity:
# [[0.         0.2566675  0.        ]
#  [0.02829698 0.25695827 0.07517471]
#  [0.07632629 0.12232554 0.1636575 ]]
#
# Jaccard Similarity:
# [[0.         0.19047619 0.        ]
#  [0.05       0.14814815 0.0952381 ]
#  [0.06666667 0.13043478 0.125     ]]
