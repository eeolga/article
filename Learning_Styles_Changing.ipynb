# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/article/blob/main/Learning_Styles_Changing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Re-import necessary libraries after code environment reset
import matplotlib.pyplot as plt
import pandas as pd

# Recreate the analysis data
categories = [
    "Work Preference\n(Group/Alone/So-so)",
    "Retention Style\n(Visual/Auditory/Writing/Kinesthetic)",
    "Input Preference\n(Talk/Listen/Read/Do)",
    "Material Preference\n(Video/Text/Exercises/Work)",
    "Activity Preference\n(Video/Text/Exercises/Work)"
]

changed_percentages = [66.7, 36, 48, 39, 31]
unchanged_percentages = [100 - c for c in changed_percentages]

# Create a DataFrame
summary_df = pd.DataFrame({
    'Category': categories,
    'Changed': changed_percentages,
    'Unchanged': unchanged_percentages
})

# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.5

bars1 = ax.barh(summary_df['Category'], summary_df['Changed'], bar_width, label='Changed', color='#4CAF50')
bars2 = ax.barh(summary_df['Category'], summary_df['Unchanged'], bar_width,
                left=summary_df['Changed'], label='Unchanged', color='#FFC107')

# Add labels and title
ax.set_xlabel('Percentage of Participant')
ax.set_title("Changes in Participants' Learning Styles After Course")
ax.legend(loc='lower right')

# Annotate bars
for bar in bars1 + bars2:
    width = bar.get_width()
    ax.annotate(f'{width:.0f}%', xy=(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2),
                xytext=(0, 0), textcoords='offset points',
                ha='center', va='center', fontsize=9, color='black')

plt.tight_layout()
