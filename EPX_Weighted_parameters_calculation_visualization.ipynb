# %% [markdown]
# <a href="https://colab.research.google.com/github/eeolga/article/blob/main/EPX_Weighted_parameters_calculation_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def calculate_weight(level_index):
    return (1 / 80) * level_index

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_2024.xlsx"  # Change this to your actual input file
    output_file = "output_EPX5310_2024.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure 'level_index' column exists
    if 'level_index' not in df.columns:
        print("Error: 'level_index' column not found in the Excel file.")
        return

    # Calculate weight
    df['Wt'] = df['level_index'].apply(calculate_weight)

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_EPX5310_2024.xlsx'.

# %%
import pandas as pd

def calculate_weight(level_index):
    return 1 / (80*level_index)

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_2024.xlsx"  # Change this to your actual input file
    output_file = "output_EPX5310_2024_2.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure 'level_index' column exists
    if 'level_index' not in df.columns:
        print("Error: 'level_index' column not found in the Excel file.")
        return

    # Calculate weight
    df['Wt'] = df['level_index'].apply(calculate_weight)

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_EPX5310_2024_2.xlsx'.

# %%
import pandas as pd

def calculate_weight(level_index, total_level_index):
    return level_index / total_level_index if total_level_index != 0 else 0

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_2024.xlsx"  # Change this to your actual input file
    output_file = "output_EPX5310_2024_3.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure 'level_index' column exists
    if 'level_index' not in df.columns:
        print("Error: 'level_index' column not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weight so that the sum of weights is 1
    df['Wt'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_EPX5310_2024_3.xlsx'.

# %%
import pandas as pd

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_2024.xlsx"  # Change this to your actual input file
    output_file = "output_EPX5310_2024_4.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure 'level_index' column exists
    if 'level_index' not in df.columns:
        print("Error: 'level_index' column not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weight so that the sum of weights is 234
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_EPX5310_2024_4.xlsx'.

# %%
import pandas as pd
import matplotlib.pyplot as plt

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def main():
    # Load the input Excel file
    input_file = "/content/input_22032025.xlsx"  # Change this to your actual input file
    output_file = "output_22032025.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure 'level_index' column exists
    if 'level_index' not in df.columns:
        print("Error: 'level_index' column not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weight so that the sum of weights is 234
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

    # Visualization
    plt.figure(figsize=(10, 6))
    plt.bar(df.index, df['Wt_ECTS'], color='skyblue', label='Tool ECTS')
    plt.xlabel('Tool Index')
    plt.ylabel('ECTS Weight')
    plt.title('E-Course Visualization Based on Tool Weight and Tool ECTS')
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.xticks(rotation=45)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_22032025.xlsx'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_2024.xlsx"  # Change this to your actual input file
    output_file = "output_visualization.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure 'level_index' column exists
    if 'level_index' not in df.columns:
        print("Error: 'level_index' column not found in the Excel file.")
        return

    # Ensure required columns exist
    if 'level_index' not in df.columns or 'tool_code' not in df.columns:
        print("Error: Required columns ('level_index', 'tool_code') not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weights
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))
    df['log_weight'] = np.log1p(df['Wt_ECTS'])  # Log transformation for visualization

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

    # 3D Visualization
    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(111, projection='3d')

    x = df['tool_code']
    y = df['Wt_ECTS']
    z = df['log_weight']

    ax.scatter(x, y, z, c='blue', marker='o', label='Tools')
    ax.set_xlabel('Tool Code')
    ax.set_ylabel('ECTS Weight')
    ax.set_zlabel('Log Weight')
    ax.set_title('3D Visualization of Tool Weights')
    ax.legend()

    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_visualization.xlsx'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_02042025.xlsx"  # Change this to your actual input file
    output_file = "output_02042025.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure required columns exist
    if 'level_index' not in df.columns or 'tool_code' not in df.columns:
        print("Error: Required columns ('level_index', 'tool_code') not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weights
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))
    df['log_weight'] = np.log1p(df['Wt_ECTS'])  # Log transformation for visualization

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

    # 3D Visualization with connection lines
    fig = plt.figure(figsize=(14, 12))
    ax = fig.add_subplot(111, projection='3d')

    x = df['tool_code']
    y = df['Wt_ECTS']
    z = df['log_weight']

    ax.scatter(x, y, z, c='blue', marker='o', label='Tools')

    # Draw connection lines between consecutive tools
    for i in range(len(df) - 1):
        ax.plot([x.iloc[i], x.iloc[i+1]], [y.iloc[i], y.iloc[i+1]], [z.iloc[i], z.iloc[i+1]], 'gray', linestyle='--')

    ax.set_xlabel('Tool Code')
    ax.set_ylabel('ECTS Weight')
    ax.set_zlabel('Log Weight')
    ax.set_title('3D Visualization of Tool Weights with Connections')
    ax.legend()

    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_02042025.xlsx'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_02042025.xlsx"  # Change this to your actual input file


    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Ensure required columns exist
    if 'level_index' not in df.columns or 'tool_code' not in df.columns:
        print("Error: Required columns ('level_index', 'tool_code') not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weights
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))
    df['log_weight'] = np.log1p(df['Wt_ECTS'])  # Log transformation for visualization



    # 3D Visualization with connection lines
    fig = plt.figure(figsize=(14, 12))
    ax = fig.add_subplot(111, projection='3d')

    x = df['tool_code']
    y = df['Wt_ECTS']
    z = df['log_weight']

    ax.scatter(x, y, z, c='blue', marker='o', label='Tools')
    ax.plot(x, y, z, color='gray', linestyle='-', linewidth=1, alpha=0.7)  # Connection lines

    for i, txt in enumerate(df['tool_code']):
        ax.text(x.iloc[i], y.iloc[i], z.iloc[i], txt, size=8, color='black')

    ax.set_xlabel('Tool Code')
    ax.set_ylabel('ECTS Weight')
    ax.set_zlabel('Log Weight')
    ax.set_title('3D Visualization of Tool Weights with Connections')
    ax.legend()

    plt.show()

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import pearsonr, spearmanr

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def analyze_validity(df):
    print("\n--- Data Model Validity Analysis ---")

    # Checking for missing values
    missing_values = df.isnull().sum()
    print("Missing Values Before Cleaning:\n", missing_values)

    # Checking for correlations between weighted parameters
    if 'Wt_ECTS' in df.columns and 'log_weight' in df.columns:
        pearson_corr, _ = pearsonr(df['Wt_ECTS'].dropna(), df['log_weight'].dropna())
        spearman_corr, _ = spearmanr(df['Wt_ECTS'].dropna(), df['log_weight'].dropna())
        print(f"Pearson Correlation (Wt_ECTS vs Log Weight): {pearson_corr:.3f}")
        print(f"Spearman Correlation (Wt_ECTS vs Log Weight): {spearman_corr:.3f}")
    else:
        print("Required weighted columns are missing in the dataset.")

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_02042025-1.xlsx"  # Change this to your actual input file


    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Handle missing values
    # The 'level' column likely has string values, so we'll use the mode instead of median
    # to fill missing values for this column
    df.fillna({
        'tool': 'Unknown',
        'level': df['level'].mode()[0],  # Use mode for 'level' column
        'assessment': 'Not Available',
        'level_index': df['level_index'].median(),  # Use median for missing level_index
    }, inplace=True)

    # Ensure required columns exist
    if 'level_index' not in df.columns or 'tool_code' not in df.columns:
        print("Error: Required columns ('level_index', 'tool_code') not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weights
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))
    df['log_weight'] = np.log1p(df['Wt_ECTS'])  # Log transformation for visualization

    # Analyze validity
    analyze_validity(df)

    # 3D Visualization with connection lines
    fig = plt.figure(figsize=(14, 14))
    ax = fig.add_subplot(111, projection='3d')

    x = df['tool_code']
    y = df['Wt_ECTS']
    z = df['log_weight']

    ax.scatter(x, y, z, c='blue', marker='o', label='Tools')
    ax.plot(x, y, z, color='gray', linestyle='-', linewidth=1, alpha=0.7)  # Connection lines

    for i, txt in enumerate(df['tool_code']):
        ax.text(x.iloc[i], y.iloc[i], z.iloc[i], txt, size=8, color='black')

    ax.set_xlabel('Tool Code')
    ax.set_ylabel('ECTS Weight')
    ax.set_zlabel('Log Weight')
    ax.set_title('3D Visualization of Tool Weights with Connections')
    ax.legend()

    plt.show()

if __name__ == "__main__":
    main()
# Out:
# --- Data Model Validity Analysis ---
# Missing Values Before Cleaning:
#  tool_code      0
# tool           0
# activity       0
# level          0
# level_index    0
# tool_weight    0
# ECTS_weight    0
# logs           0
# log_weight     0
# Wt_ECTS        0
# dtype: int64
# Pearson Correlation (Wt_ECTS vs Log Weight): 0.959
# Spearman Correlation (Wt_ECTS vs Log Weight): 1.000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import pearsonr, spearmanr

def calculate_weight(level_index, total_level_index):
    return (level_index / total_level_index) * 234 if total_level_index != 0 else 0

def analyze_validity(df):
    print("\n--- Data Model Validity Analysis ---")

    # Checking for missing values
    missing_values = df.isnull().sum()
    print("Missing Values Before Cleaning:\n", missing_values)

    # Checking for correlations between weighted parameters
    if 'Wt_ECTS' in df.columns and 'tool_log' in df.columns:
        pearson_corr, _ = pearsonr(df['Wt_ECTS'].dropna(), df['tool_log'].dropna())
        spearman_corr, _ = spearmanr(df['Wt_ECTS'].dropna(), df['tool_log'].dropna())
        print(f"Pearson Correlation (Wt_ECTS vs Tool Log): {pearson_corr:.3f}")
        print(f"Spearman Correlation (Wt_ECTS vs Tool Log): {spearman_corr:.3f}")
    else:
        print("Required weighted columns are missing in the dataset.")

def visualize_correlations(df):
    plt.figure(figsize=(6, 4))
    correlation_matrix = df[['tool_weight', 'tool_ECTS', 'tool_log', 'tool_performance']].corr()
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title("Correlation Matrix of Tool Parameters")
    plt.show()

def main():
    # Load the input Excel file
    input_file = "/content/input_EPX5310_02042025-2.xlsx"  # Change this to your actual input file
    output_file = "output_2.xlsx"

    # Read the Excel file
    try:
        df = pd.read_excel(input_file)
    except FileNotFoundError:
        print(f"Error: File '{input_file}' not found.")
        return

    # Handle missing values
    # Use the mode (most frequent value) for the 'level' column,
    # as it likely contains categorical/string data.
    # Use the median for numeric columns like 'level_index'.
    df.fillna({
        'tool': 'Unknown',
        'level': df['level'].mode()[0],  # Use mode for 'level' column
        'assessment': 'Not Available',
        'level_index': df['level_index'].median(),  # Use median for missing level_index
    }, inplace=True)

    # Ensure required columns exist
    if 'level_index' not in df.columns or 'tool_code' not in df.columns:
        print("Error: Required columns ('level_index', 'tool_code') not found in the Excel file.")
        return

    # Calculate total level_index sum
    total_level_index = df['level_index'].sum()

    # Calculate weights
    df['Wt_ECTS'] = df['level_index'].apply(lambda x: calculate_weight(x, total_level_index))
    df['tool_log'] = np.log1p(df['Wt_ECTS'])  # Log transformation for visualization

    # Calculate tool performance
    df['tool_performance'] = (df['tool_weight'] * df['tool_ECTS']) / df['tool_log']

    # Save to output Excel file
    df.to_excel(output_file, index=False)
    print(f"Results saved to '{output_file}'.")

    # Analyze validity
    analyze_validity(df)

    # Visualize correlation matrix
    visualize_correlations(df)

    # 3D Visualization with connection lines
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111, projection='3d')

    x = df['tool_code']
    y = df['Wt_ECTS']
    z = df['tool_log']

    ax.scatter(x, y, z, c='blue', marker='o', label='Tools')
    ax.plot(x, y, z, color='gray', linestyle='-', linewidth=1, alpha=0.7)  # Connection lines

    for i, txt in enumerate(df['tool_code']):
        ax.text(x.iloc[i], y.iloc[i], z.iloc[i], txt, size=8, color='black')

    ax.set_xlabel('Tool Code')
    ax.set_ylabel('Tool ECTS')
    ax.set_zlabel('Tool Log')
    ax.set_title('3D Visualization of Tool Weights with Connections')
    ax.legend()

    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Results saved to 'output_2.xlsx'.
#
# --- Data Model Validity Analysis ---
# Missing Values Before Cleaning:
#  tool_code            0
# tool                 0
# activity             0
# level                0
# level_index          0
# tool_weight          0
# tool_ECTS            0
# logs                 0
# tool_log             0
# tool_performance    15
# Wt_ECTS              0
# dtype: int64
# Pearson Correlation (Wt_ECTS vs Tool Log): 0.959
# Spearman Correlation (Wt_ECTS vs Tool Log): 1.000
